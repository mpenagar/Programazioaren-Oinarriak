# %%
class Myset(object):
    
    def __init__(self,it=()):
        pass
        
    def add(self, value):
        pass
    
    def addall(self, it):
        pass
    
    def __len__(self):
        pass
    
    def __str__(self):
        pass
    
    def __contains__(self, value):
        pass
    
    def __eq__(self, other):
        pass
    
    def __ne__(self, other):
        pass
    
    def __repr__(self):
        pass
    
    def __iter__(self):
        pass
    
    def remove(self, value):
        pass
    
    def removeall(self, it):
        pass
    
    def union(self, other):
        pass
    
    def __or__(self, other):
        pass
    
    def intersection(self, other):
        pass
    
    def __and__(self, other):
        pass
        

s = Myset()
print(s)
s = Myset("outdoluydñiyudluydol")
print(s)
# Out:
# kk
# kk
