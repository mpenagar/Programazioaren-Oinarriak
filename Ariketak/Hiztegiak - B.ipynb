# %% [markdown]
# ## 1
# Testu fitxategi batetako hitzen histograma kalkulatzen duen funtzioa sortu. Suposatu testu fitxategian agertzen diren karaktere guztiak alfabetikoak edo hutsunea direla.

# %%
def histograma(filename):
    f = open(filename)
    h = {}
    for line in f :
        for w in line.split():
            #if w in h :
            #    h[w] += 1
            #else :
            #    h[w] = 1
            h[w] = h.get(w,0) + 1    
    f.close()
    return h
     
print(*histograma("text.txt").items())
# Out:
# ('in', 2) ('the', 21) ('beginning', 1) ('god', 7) ('created', 1) ('heaven', 1) ('and', 15) ('earth', 2) ('was', 4) ('without', 1) ('form', 1) ('void', 1) ('darkness', 3) ('upon', 2) ('face', 2) ('of', 4) ('deep', 1) ('spirit', 1) ('moved', 1) ('waters', 4) ('said', 2) ('let', 3) ('there', 3) ('be', 2) ('light', 5) ('saw', 1) ('that', 1) ('it', 2) ('good', 1) ('divided', 1) ('from', 2) ('called', 2) ('day', 2) ('he', 1) ('night', 1) ('evening', 1) ('morning', 1) ('were', 1) ('first', 1) ('a', 1) ('firmament', 1) ('midst', 1) ('divide', 1)

# %% [markdown]
# ## 3
# Hitz histograma bat jaso eta alderantzizko histograma bueltatuko duen funtzioa sortu. Hau da, bueltatutako hiztegiaren gakoak agerpen kopuruak izango dira eta balioak berriz hitz zerrendak.

# %%
def amargotsih(h):
    h2 = {}
    for ,b in h.items():
    
    
    return h2


h = histograma("text.txt")
amargotsih(h)
