# %% [markdown]
# ## 1
# Testu fitxategi batetako hitzen histograma kalkulatzen duen funtzioa sortu. Suposatu testu fitxategian agertzen diren karaktere guztiak alfabetikoak edo hutsunea direla.

# %%
def histograma(filename):
    f = open(filename)
    h = {}
    for line in f :
        for w in line.split():
            #if w in h :
            #    h[w] += 1
            #else :
            #    h[w] = 1
            h[w] = h.get(w,0) + 1    
    f.close()
    return h
     
print(*histograma("text.txt").items())
# Out:
# ('in', 2) ('the', 21) ('beginning', 1) ('god', 7) ('created', 1) ('heaven', 1) ('and', 15) ('earth', 2) ('was', 4) ('without', 1) ('form', 1) ('void', 1) ('darkness', 3) ('upon', 2) ('face', 2) ('of', 4) ('deep', 1) ('spirit', 1) ('moved', 1) ('waters', 4) ('said', 2) ('let', 3) ('there', 3) ('be', 2) ('light', 5) ('saw', 1) ('that', 1) ('it', 2) ('good', 1) ('divided', 1) ('from', 2) ('called', 2) ('day', 2) ('he', 1) ('night', 1) ('evening', 1) ('morning', 1) ('were', 1) ('first', 1) ('a', 1) ('firmament', 1) ('midst', 1) ('divide', 1)

# %% [markdown]
# ## 3
# Hitz histograma bat jaso eta alderantzizko histograma bueltatuko duen funtzioa sortu. Hau da, bueltatutako hiztegiaren gakoak agerpen kopuruak izango dira eta balioak berriz hitz zerrendak.

# %%
def amargotsih(h):
    h2 = {}
    for w,n in h.items():
        if n not in h2:
            h2[n]=[]
        h2[n].append(w)
    return h2
def amargotsih(h):
    h2 = {}
    for w,n in h.items():
        h2.setdefault(n,[]).append(w)
    return h2

h = histograma("text.txt")
h2 = amargotsih(h)
print(*h2.items(), sep="\n")
# Out:
# (2, ['in', 'earth', 'upon', 'face', 'said', 'be', 'it', 'from', 'called', 'day'])
# (21, ['the'])
# (1, ['beginning', 'created', 'heaven', 'without', 'form', 'void', 'deep', 'spirit', 'moved', 'saw', 'that', 'good', 'divided', 'he', 'night', 'evening', 'morning', 'were', 'first', 'a', 'firmament', 'midst', 'divide'])
# (7, ['god'])
# (15, ['and'])
# (4, ['was', 'of', 'waters'])
# (3, ['darkness', 'let', 'there'])
# (5, ['light'])

# %%
d = {1:2,3:4,5:6}
print(d.values())
for x in d.values():
    print(x)
print(list(d.values()))
print(tuple(d.values()))
print(*d.values())
# Out:
# 3
# 2
# 4
# 6
# [2, 4, 6]
# (2, 4, 6)
# 2 4 6

# %%
d = {1:2,3:4,5:6}
print(d.items())
for x in d.items():
    print(x)
print(list(d.items()))
print(tuple(d.items()))
print(*d.items())
# Out:
# dict_items([(1, 2), (3, 4), (5, 6)])
# (1, 2)
# (3, 4)
# (5, 6)
# [(1, 2), (3, 4), (5, 6)]
# ((1, 2), (3, 4), (5, 6))
# (1, 2) (3, 4) (5, 6)

# %%
d = {"jon":33, "ane":22, "luis":18}
print(d)
# Out:
# {'jon': 33, 'ane': 22, 'luis': 18}

# %%
kk = "ljuyhfljghydiñufóuflpuydflouydlylñ"
s = se
