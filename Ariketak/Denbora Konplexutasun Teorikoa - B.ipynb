# %% [markdown]
# ## 3
# Zenbaki zerrenda batetako elementu bakoitien batura

# %%
def bakoitien_batura(z):
    b = 0
    for x in z :
        if x%2 == 1 :
            b += x
    return b

# %% [markdown]
# ```python
# def bakoitien_batura(z):
#     b = 0
#     for x in z :
#         if x%2 == 1 :
#             b += x
#     return b
# ```
