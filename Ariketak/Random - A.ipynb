# %% [markdown]
# ## 5
# random moduloko random funtzioa edo aurreko edozein funtzio erabiliz, sortu ezazu population elementu sekuentziatik auzazko k elementu dituen zerrenda bueltatuko duen sample(population, k) funtzioa

# %%
from random import randrange 
def sample(population, k):
    if k > len(population):
        raise ValueError(f'{k} > len(population) = {len(population)}')
    z = []
    while len(z) < k :
        i = randrange(len(population))
        #print(i)
        if i not in z :
            z.append(i)
    z2 = []
    for i in z :
        z2.append(population[i])
    return z2
        
sample("abcdefghi", 4)
#sample("aaaaaabbbbbbbcdef", 4)
# Out:
# ['f', 'c', 'b', 'h']

# %%
from random import randrange 
def sample(population, k):
    if k > len(population):
        raise ValueError(f'{k} > len(population) = {len(population)}')
    s = set()
    while len(s) < k :
        i = randrange(len(population))
        print(i)
        s.add(i)
    z2 = []
    for i in s :
        z2.append(population[i])
    return z2
        
sample("abcdefghi", 4)
#sample("aaaaaabbbbbbbcdef", 4)
# Out:
# 2
# 8
# 8
# 5
# 0
# ['i', 'a', 'c', 'f']

# %%
pop = "abcdefghi" * 100
n = len(pop)
print(n)
sample(pop, 4)
# Out:
# 900
# 610
# 264
# 553
# 778
# ['d', 'e', 'h', 'e']
