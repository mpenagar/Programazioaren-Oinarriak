# %%
from random import random

# %% [markdown]
# ## 2
# random moduloko random funtzioa edo aurreko edozein funtzio erabiliz, sortu ezazu range(start,stop[,step]) sekuentziako auzazko zenbaki osoa bueltatuko duen randrange(start,stop[,step]) funtzioa.

# %%
# 1. ariketa eginda badago, hau ez da beharrezkoa
from random import randint

# %%
import random
help(random.randrange)
# Out:
# Help on method randrange in module random:
#
# randrange(start, stop=None, step=1, _int=<class 'int'>) method of random.Random instance
#     Choose a random item from range(start, stop[, step]).
#
#     This fixes the problem with randint() which includes the
#     endpoint; in Python this is usually not what you want.

# %%
def randrange(start, stop=None, step=1):
    # 1. zerrenda bat sortu tarteko elementu guztiekin
    if stop == None:
        start,stop = 0,start
    if start >= stop :
        raise ValueError('start >=')
    z = []
    i = start
    while i < stop :
        z.append(i)
        i += step
    # 2. Auzazko elementu bat aukeratu
    pos = randint(0,len(z)-1)
    return z[pos]
    
    
randrange(7,3)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-85-8a61ff33b556> in <module>
#      13
#      14
# ---> 15 randrange(7,3)
#      16
#
# <ipython-input-85-8a61ff33b556> in randrange(start, stop, step)
#       9         i += step
#      10     # 2. Auzazko elementu bat aukeratu
# ---> 11     pos = randint(0,len(z)-1)
#      12     return z[pos]
#      13
#
# /usr/local/lib/python3.7/random.py in randint(self, a, b)
#     220         """
#     221
# --> 222         return self.randrange(a, b+1)
#     223
#     224     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# /usr/local/lib/python3.7/random.py in randrange(self, start, stop, step, _int)
#     198             return istart + self._randbelow(width)
#     199         if step == 1:
# --> 200             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#     201
#     202         # Non-unit step argument supplied.
#
# ValueError: empty range for randrange() (0,0, 0)
